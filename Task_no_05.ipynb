# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamRafiqueButt/AI-ML-InterTask/blob/main/Task_no_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step1: install libaries torch for AI engine
# !pip install transformers torch

# %%
#Step 2: Hugging face pipeline import kar raha hai
from transformers import pipeline

# %%
# GPT2 free model load ho raha hai
chatbot = pipeline("text-generation", model="gpt2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ...

# %%
#Step 3:Safety functions
def safety_check(question):
    dangerous_words = ["overdose", "suicide", "self harm"]

    for word in dangerous_words:
        if word in question.lower():
            return False # unsafe question
    return True # safe question

# %%
# Step 5:AI response function
def get_health_response(user_question):


# Step 6:AI ka samjhny ky liya prompt banya hai
    prompt = f"""
You are a helpful medical assistant.
Give simple, safe and general health advice.

Question: {user_question}
Answer:
"""
#Step 7:chatbox text generate karna
    result = chatbot(prompt, max_length=100, num_return_sequences=1)

#Step 8:AI ka generated text return karna
    return result[0]["generated_text"]

# %%
#Step 9:Chatbox start message
print(" Health Chatbot Started (Google Colab)")
print("Type 'exit' to stop\n")


#Step 10:infinite looop (ask again again questions )
while True:


    user_input = input("Ask health question: ")

    if user_input.lower() == "exit":
        print("Goodbye 👋")
        break

    if not safety_check(user_input):
        print("Sorry, unsafe question. Please consult a doctor.")
        continue

    answer = get_health_response(user_input)
    print("\nBot:", answer, "\n")
# Out:
#  Health Chatbot Started (Google Colab)
# Type 'exit' to stop
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Bot:
# You are a helpful medical assistant.
# Give simple, safe and general health advice.
#
# Question: what is fever ?
# Answer:
#
# The symptoms of fever are usually mild but are often fatal.
#
# What is your fever?
#
# What is your fever?
#
# What is your fever?
#
# It's your body that's producing the hormones that cause colds.
#
# ...
